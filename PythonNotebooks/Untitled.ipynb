# %%
import numpy as np
import pandas as pd
full_df = pd.read_csv("numeric_train.csv")
full_df_group = full_df.groupby(by=["customer_ID"]) # .agg(lambda x: )
columns_ = list(full_df.columns.values)
df_list = []

#print(new_df)
for grp, data in full_df_group :
     #if(int(grp) == 14981 or int(grp) == 217):
    x = list(data["C_previous"])
    z = x[len(x) - 1]
    p = list(data["duration_previous"])
    q = p[len(p) - 1]
    #grp_list = [grp]*len(x)
    #grp_df = pd.DataFrame(grp_list, columns=["customer_ID"])
    #print(grp_df)
    #frames = [data.replace(to_replace={'C_previous' : {np.float64('nan') : z}, 'duration_previous' : {np.float64('nan') : q}})]
    #print(type(data.replace(to_replace={'C_previous' : {np.float64('nan') : z}, 'duration_previous' : {np.float64('nan') : q}})))
    #result = pd.concat(frames, axis=1)
    #print(result)
    #new_df = new_df.append(data.replace(to_replace={'C_previous' : {np.float64('nan') : z}, 'duration_previous' : {np.float64('nan') : q}}))
    df_list.append(data.replace(to_replace={'C_previous' : {np.float64('nan') : z}, 'duration_previous' : {np.float64('nan') : q}}))
    #print(new_df)
    #break
    #print(new_df)
    #print(type(data.replace(to_replace={'C_previous' : {np.float64('nan') : z}}))) # , inplace=True

result = pd.concat(df_list)
# Out:
# 67663
# Empty DataFrame
# Columns: []
# Index: []

# %%
result = pd.concat(df_list)
result[0:20]
# Out:
#        customer_ID  shopping_pt  record_type  day  time  state  location  \
# 56157          217            1            0    2     1     25     30328
# 56158          217            2            0    2     1     25     30328
# 56159          217            3            0    2     1     25     30328
# 56160          217            4            0    2     1     25     30328
# 56161          217            5            0    2     1     25     30328
# 56162          217            6            1    2     1     25     30328
# 56132          233            1            0    2     2      2     30352
# 56133          233            2            0    2     2      2     30352
# 56134          233            3            0    2     2      2     30352
# 56135          233            4            1    1     1      2     30352
# 56232          245            1            0    2     1     22     30373
# 56233          245            2            0    2     1     22     30373
# 56234          245            3            0    2     1     22     30373
# 56235          245            4            0    2     1     22     30373
# 56236          245            5            0    2     1     22     30373
# 56237          245            6            0    2     1     22     30373
# 56238          245            7            0    2     1     22     30373
# 56239          245            8            1    2     1     22     30373
# 56225          253            1            0    2     2     11     30385
# 56226          253            2            0    2     2     11     30385
#
#        group_size  homeowner  car_age  car_value  risk_factor  age_oldest  \
# 56157           1          0       10          5            4          28
# 56158           1          0       10          5            4          28
# 56159           1          0       10          5            4          28
# 56160           1          0       10          5            4          28
# 56161           1          0       10          5            4          28
# 56162           1          0       10          5            4          28
# 56132           2          1        3          4            3          62
# 56133           2          1        3          4            3          62
# 56134           2          1        3          4            3          62
# 56135           2          1        3          4            3          62
# 56232           1          0        7          4          NaN          21
# 56233           1          0        7          4          NaN          21
# 56234           1          0        7          4          NaN          21
# 56235           1          0        7          4          NaN          21
# 56236           1          0        7          4          NaN          21
# 56237           1          0        7          4          NaN          21
# 56238           1          0        7          4          NaN          21
# 56239           1          0        7          4          NaN          21
# 56225           1          1        2          6            3          31
# 56226           1          1        2          6            3          31
#
#        age_youngest  married_couple  C_previous  duration_previous  policy  \
# 56157            28               0           3                 13       1
# 56158            28               0           3                 13       1
# 56159            28               0           3                 13       1
# 56160            28               0           3                 13       1
# 56161            28               0           3                 13       1
# 56162            28               0           3                 13       1
# 56132            60               1           3                  3       3
# 56133            60               1           3                  3       3
# 56134            60               1           3                  3       2
# 56135            60               1           3                  3       2
# 56232            21               0           2                  4       3
# 56233            21               0           2                  4       3
# 56234            21               0           2                  4       3
# 56235            21               0           2                  4       3
# 56236            21               0           2                  4       3
# 56237            21               0           2                  4       3
# 56238            21               0           2                  4       3
# 56239            21               0           2                  4       3
# 56225            31               0           1                 13       2
# 56226            31               0           1                 13       2
#
#        cost
# 56157   758
# 56158   758
# 56159   758
# 56160   733
# 56161   734
# 56162   734
# 56132   632
# 56133   623
# 56134   630
# 56135   629
# 56232   684
# 56233   684
# 56234   684
# 56235   684
# 56236   688
# 56237   688
# 56238   688
# 56239   708
# 56225   662
# 56226   630
